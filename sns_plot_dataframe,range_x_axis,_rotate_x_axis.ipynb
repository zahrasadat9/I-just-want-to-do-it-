# %% [markdown]
# <a href="https://colab.research.google.com/github/zahrasadat9/I-just-want-to-do-it-/blob/main/sns_plot_dataframe%2Crange_x_axis%2C_rotate_x_axis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

a= pd.DataFrame({'Name': ['Tom', 'Joseph', 'Krish', 'John'], 'Age': [20, 21, 19, 18]}   )
# blue grid lined BG
sns.set_theme()
# fig size
plt.figure(figsize=(15,8))

ax= sns.histplot(a,kde=True,binwidth=1)
# range of plot
ax.set_xticks(range(15,25));
# rotate the x axis labels without changing hem
ax.tick_params(axis='x', labelrotation=90);
